# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from nltk.tokenize import RegexpTokenizer
import pandas as pd
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
df = pd.read_csv('WEEK_2_DESCRIPTIONS.csv').drop('Unnamed: 0', axis=1)

# %%
def bin_scores(score):
    if score > 60:
        if score > 75:
            return 2
        return 1
    return 0

df['success'] = df['Critic_Score'].apply(bin_scores)

def clean_text(text):
    
    # Removes punctuation
    words = [''.join(ch for ch in s if ch not in string.punctuation)\
             for s in text.split()]
    
    # Returns the lower-case string
    return ' '.join(words).lower()

df.plots = df.plots.apply(clean_text)

# %%
# Out:
#                                          Name Platform  Year_of_Release  \
# 0                                  Wii Sports      Wii           2006.0
# 1                              Mario Kart Wii      Wii           2008.0
# 2                           Wii Sports Resort      Wii           2009.0
# 3                       New Super Mario Bros.       DS           2006.0
# 4                                    Wii Play      Wii           2006.0
# ...                                       ...      ...              ...
# 5494  Super Robot Taisen: Original Generation      GBA           2002.0
# 5495           Mortal Kombat: Deadly Alliance      GBA           2002.0
# 5496        Metal Gear Solid V: Ground Zeroes       PC           2014.0
# 5497                                   Breach       PC           2011.0
# 5498                                  15 Days       PC           2009.0
#
#              Genre                     Publisher  NA_Sales  EU_Sales  \
# 0           Sports                      Nintendo     41.36     28.96
# 1           Racing                      Nintendo     15.68     12.76
# 2           Sports                      Nintendo     15.61     10.93
# 3         Platform                      Nintendo     11.28      9.14
# 4             Misc                      Nintendo     13.96      9.18
# ...            ...                           ...       ...       ...
# 5494  Role-Playing                     Banpresto      0.01      0.00
# 5495      Fighting                  Midway Games      0.01      0.00
# 5496        Action  Konami Digital Entertainment      0.00      0.01
# 5497       Shooter                     Destineer      0.01      0.00
# 5498     Adventure             DTP Entertainment      0.00      0.01
#
#       JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0         3.77         8.45         82.53          76.0          51.0
# 1         3.79         3.29         35.52          82.0          73.0
# 2         3.28         2.95         32.77          80.0          73.0
# 3         6.50         2.88         29.80          89.0          65.0
# 4         2.93         2.84         28.92          58.0          41.0
# ...        ...          ...           ...           ...           ...
# 5494      0.00         0.00          0.01          72.0          13.0
# 5495      0.00         0.00          0.01          81.0          12.0
# 5496      0.00         0.00          0.01          80.0          20.0
# 5497      0.00         0.00          0.01          61.0          12.0
# 5498      0.00         0.00          0.01          63.0           6.0
#
#      User_Score  User_Count           Developer Rating  \
# 0             8       322.0            Nintendo      E
# 1           8.3       709.0            Nintendo      E
# 2             8       192.0            Nintendo      E
# 3           8.5       431.0            Nintendo      E
# 4           6.6       129.0            Nintendo      E
# ...         ...         ...                 ...    ...
# 5494        tbd         NaN           Banpresto      T
# 5495        8.8         9.0     Criterion Games      M
# 5496        7.6       412.0  Kojima Productions      M
# 5497        5.8        43.0        Atomic Games      T
# 5498        5.8         8.0   DTP Entertainment    NaN
#
#                                                   plots  success
# 0     wii sports consists of five separate sports ga...        2
# 1     mario kart wii is a kart racing game featuring...        2
# 2     wii sports resort is a sports video game set i...        2
# 3     new super mario bros is a sidescrolling video ...        2
# 4     wii play is a party game consisting of nine mi...        0
# ...                                                 ...      ...
# 5494  original generation offers the player a choice...        1
# 5495  like all of the mortal kombat games deadly all...        2
# 5496  players control snake through the game map and...        2
# 5497  there are four game modes infiltration retriev...        1
# 5498  the player controls three characters who are a...        1
#
# [5499 rows x 18 columns]

# %%
X = df.plots
y = df.success

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train
# Out:
# 3987    vendetta separates itself from other first per...
# 1127    bayonetta is a singleplayer thirdperson 3d act...
# 4016    combat is split between a turnbased battlefiel...
# 468     dark souls is a thirdperson action roleplaying...
# 4582    lifelines selling point is its advanced ai sys...
#                               ...
# 2804    the warriors is an actionadventure survival ga...
# 5237    toxic grind is a fairly conventional extreme s...
# 221     while bad company 2 is primarily a firstperson...
# 4622    the game is a fantasy simulationtype rpg based...
# 1864    the game has the player in a similar role as i...
# Name: plots, Length: 4124, dtype: object

# %%
tf = TfidfVectorizer(stop_words='english', max_features=1000)
X_train_tf = tf.fit_transform(X_train)
X_test_tf = tf.transform(X_test)

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')

df["tokens"] = df["plots"].apply(tokenizer.tokenize)
df.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 1         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 2      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 3  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 4               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     15.68     12.76      3.79         3.29         35.52          82.0
# 2     15.61     10.93      3.28         2.95         32.77          80.0
# 3     11.28      9.14      6.50         2.88         29.80          89.0
# 4     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating  \
# 0          51.0          8       322.0  Nintendo      E
# 1          73.0        8.3       709.0  Nintendo      E
# 2          73.0          8       192.0  Nintendo      E
# 3          65.0        8.5       431.0  Nintendo      E
# 4          41.0        6.6       129.0  Nintendo      E
#
#                                                plots  success  \
# 0  wii sports consists of five separate sports ga...        2
# 1  mario kart wii is a kart racing game featuring...        2
# 2  wii sports resort is a sports video game set i...        2
# 3  new super mario bros is a sidescrolling video ...        2
# 4  wii play is a party game consisting of nine mi...        0
#
#                                               tokens
# 0  [wii, sports, consists, of, five, separate, sp...
# 1  [mario, kart, wii, is, a, kart, racing, game, ...
# 2  [wii, sports, resort, is, a, sports, video, ga...
# 3  [new, super, mario, bros, is, a, sidescrolling...
# 4  [wii, play, is, a, party, game, consisting, of...

# %%
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from nltk.tokenize import RegexpTokenizer



all_words = [word for tokens in df["tokens"] for word in tokens]
VOCAB = sorted(list(set(all_words)))

EMBEDDING_DIM = 300
MAX_SEQUENCE_LENGTH = 35
VOCAB_SIZE = len(VOCAB)

VALIDATION_SPLIT=.2
tokenizer = Tokenizer(num_words=VOCAB_SIZE)
tokenizer.fit_on_texts(df["plots"].tolist())
sequences = tokenizer.texts_to_sequences(df["plots"].tolist())

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

cnn_data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
labels = to_categorical(np.asarray(df["success"]))

indices = np.arange(cnn_data.shape[0])
np.random.shuffle(indices)
cnn_data = cnn_data[indices]
labels = labels[indices]
num_validation_samples = int(VALIDATION_SPLIT * cnn_data.shape[0])

embedding_weights = np.zeros((len(word_index)+1, EMBEDDING_DIM))
for word,index in word_index.items():
    embedding_weights[index,:] = word2vec[word] if word in word2vec else np.random.rand(EMBEDDING_DIM)
print(embedding_weights.shape)
# Out:
# Found 42359 unique tokens.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d681e68eb4d1> in <module>
#      33 embedding_weights = np.zeros((len(word_index)+1, EMBEDDING_DIM))
#      34 for word,index in word_index.items():
# ---> 35     embedding_weights[index,:] = word2vec[word] if word in word2vec else np.random.rand(EMBEDDING_DIM)
#      36 print(embedding_weights.shape)
#
# NameError: name 'word2vec' is not defined

# %%
from keras.layers import Dense, Input, Flatten, Dropout, Concatenate
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.layers import LSTM, Bidirectional
from keras.models import Model

def ConvNet(embeddings, max_sequence_length, num_words, embedding_dim, labels_index, trainable=False, extra_conv=True):
    
    embedding_layer = Embedding(num_words,
                            embedding_dim,
                            weights=[embeddings],
                            input_length=max_sequence_length,
                            trainable=trainable)

    sequence_input = Input(shape=(max_sequence_length,), dtype='int32')
    embedded_sequences = embedding_layer(sequence_input)

    # Yoon Kim model (https://arxiv.org/abs/1408.5882)
    convs = []
    filter_sizes = [3,4,5]

    for filter_size in filter_sizes:
        l_conv = Conv1D(filters=128, kernel_size=filter_size, activation='relu')(embedded_sequences)
        l_pool = MaxPooling1D(pool_size=3)(l_conv)
        convs.append(l_pool)

    l_merge = Concatenate(concat_axis=1)(convs)

    # add a 1D convnet with global maxpooling, instead of Yoon Kim model
    conv = Conv1D(filters=128, kernel_size=3, activation='relu')(embedded_sequences)
    pool = MaxPooling1D(pool_size=3)(conv)
    
    if extra_conv==True:
        x = Dropout(0.5)(l_merge)  
    else:
        # Original Yoon Kim model
        x = Dropout(0.5)(pool)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    #x = Dropout(0.5)(x)

    preds = Dense(labels_index, activation='softmax')(x)

    model = Model(sequence_input, preds)
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['acc'])

    return model

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(1000,1,1)))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer='rmsprop',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(X_train_tf, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-ad69fae8fd86> in <module>
# ----> 1 model.fit(X_train_tf, y_train)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1152             sample_weight=sample_weight,
#    1153             class_weight=class_weight,
# -> 1154             batch_size=batch_size)
#    1155
#    1156         # Prepare validation data.
#
# ~\anaconda3\envs\learn-env\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     577             feed_input_shapes,
#     578             check_batch_axis=False,  # Don't enforce the batch size.
# --> 579             exception_prefix='input')
#     580
#     581         if y is not None:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     133                         ': expected ' + names[i] + ' to have ' +
#     134                         str(len(shape)) + ' dimensions, but got array '
# --> 135                         'with shape ' + str(data_shape))
#     136                 if not check_batch_axis:
#     137                     data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected dense_2_input to have 4 dimensions, but got array with shape (4124, 1000)
